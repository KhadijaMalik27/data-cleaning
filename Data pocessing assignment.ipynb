# %% [markdown]
# # What is pandas  :
#
# - A	very	powerful	package	of	Python	for
# manipulating	tables
# - Built	on	top	of	numpy,	so	is	efficient
# - Save	you	a	lot	of	effort	from	writing	lower
# python	code	for	manipulating,	extracting,	and
# deriving	tables	related	information
# - Easy	visualization	with	Matplotlib
# - Main	data	structures	–	Series	and	DataFrame

# %% [markdown]
# ## Data Processing with Python Pandas  :
# Pandas is a popular software library for Python which includes a number of useful data processing tools. It is free and relatively easy to learn, with a community which provides support and documentation. It is more powerful than Excel and is able to produce high-quality figures.
#
# Building on Introduction to Python, this course teaches the beginnings of data processing in Python using the Pandas library. You will learn the basic commands of the package with hands-on examples using the Jupyter Notebook environment.
#
# ## Function it provides  :
#
# - Selecting rows of data
# - Selecting columns of data
# - Cutting and joining data
# - Reading and writing data
# - Producing graphs from the data

# %% [markdown]
# ## Reading CSV file through pandas  :

# %%
import pandas as  pd

df =pd.read_csv('Cuisine_rating.csv')

# %% [markdown]
# ## Opening dataset in pandas  :

# %%
df
# Out:
#      User ID  Area code            Location  Gender   YOB Marital Status  \
# 0          1        153  Upper East Side,NY  Female  2006         Single
# 1          2        123       St. George,NY  Female  1991        Married
# 2          3        122  Upper West Side,NY    Male  1977         Single
# 3          4        153  Upper East Side,NY  Female  1956        Married
# 4          5        129     Central Park,NY    Male  1997         Single
# ..       ...        ...                 ...     ...   ...            ...
# 195      196        175       St. George,NY  Female  1982         Single
# 196      197        170  Upper West Side,NY  Female  2000        Married
# 197      198        160       St. George,NY  Female  2006         Single
# 198      199        130       St. George,NY    Male  2002        Married
# 199      200        140  Upper East Side,NY    Male  2005        Married
#
#          Activity  Budget  Cuisines  Alcohol     Smoker  Food Rating  \
# ...

# %% [markdown]
# ## Location column letters titles :
#
# Making lower case letters of country to upper case  :

# %%
df["Location"].str.title()

df
# Out:
#      User ID  Area code            Location  Gender   YOB Marital Status  \
# 0          1        153  Upper East Side,NY  Female  2006         Single
# 1          2        123       St. George,NY  Female  1991        Married
# 2          3        122  Upper West Side,NY    Male  1977         Single
# 3          4        153  Upper East Side,NY  Female  1956        Married
# 4          5        129     Central Park,NY    Male  1997         Single
# ..       ...        ...                 ...     ...   ...            ...
# 195      196        175       St. George,NY  Female  1982         Single
# 196      197        170  Upper West Side,NY  Female  2000        Married
# 197      198        160       St. George,NY  Female  2006         Single
# 198      199        130       St. George,NY    Male  2002        Married
# 199      200        140  Upper East Side,NY    Male  2005        Married
#
#          Activity  Budget  Cuisines  Alcohol     Smoker  Food Rating  \
# ...

# %% [markdown]
# ## Spliting city and state with new column   :

# %%
df["Location"].str.split(",", n=1 , expand = True)
# Out:
#                    0   1
# 0    Upper East Side  NY
# 1         St. George  NY
# 2    Upper West Side  NY
# 3    Upper East Side  NY
# 4       Central Park  NY
# ..               ...  ..
# 195       St. George  NY
# 196  Upper West Side  NY
# 197       St. George  NY
# 198       St. George  NY
# 199  Upper East Side  NY
#
# [200 rows x 2 columns]

# %% [markdown]
# ## Saving new column with state information  :

# %%
df [ [ "City" , "State"  ] ] =df["Location"].str.split("," , n=1 , expand = True)

# %% [markdown]
# ## Viewing new columns  :
# As we can see I have splited the address into city and state now we have to remove location column containing uncleaned address :

# %%
df.head()
# Out:
#    User ID  Area code            Location  Gender   YOB Marital Status  \
# 0        1        153  Upper East Side,NY  Female  2006         Single
# 1        2        123       St. George,NY  Female  1991        Married
# 2        3        122  Upper West Side,NY    Male  1977         Single
# 3        4        153  Upper East Side,NY  Female  1956        Married
# 4        5        129     Central Park,NY    Male  1997         Single
#
#        Activity  Budget  Cuisines  Alcohol     Smoker  Food Rating  \
# 0  Professional       3  Japanese     Never     Never            5
# 1       Student       3    Indian     Never  Socially            1
# 2       Student       5   Seafood     Often     Often            5
# 3  Professional       5  Japanese     Never  Socially            3
# 4       Student       4  Filipino  Socially     Never            2
#
#    Service Rating  Overall Rating Often A S             city State  \
# ...

# %% [markdown]
# ## Removing Unclean and useless columns  :

# %%
df = df.drop(labels= ["Location"], axis= 1)

# %% [markdown]
# ## Removing Duplicates

# %%
df.drop_duplicates()
# Out:
#      User ID  Area code  Gender   YOB Marital Status      Activity  Budget  \
# 0          1        153  Female  2006         Single  Professional       3
# 1          2        123  Female  1991        Married       Student       3
# 2          3        122    Male  1977         Single       Student       5
# 3          4        153  Female  1956        Married  Professional       5
# 4          5        129    Male  1997         Single       Student       4
# ..       ...        ...     ...   ...            ...           ...     ...
# 195      196        175  Female  1982         Single  Professional       4
# 196      197        170  Female  2000        Married       Student       4
# 197      198        160  Female  2006         Single  Professional       5
# 198      199        130    Male  2002        Married       Student       3
# 199      200        140    Male  2005        Married       Student       4
#
#      Cuisines  Alcohol     Smoker  Food Rating  Service Rating  \
# ...

# %% [markdown]
# ## Counting all null values

# %%
df.isnull().sum()
# Out:
# User ID            0
# Area code          0
# Gender             0
# YOB                0
# Marital Status    14
# Activity           9
# Budget             0
# Cuisines           8
# Alcohol            0
# Smoker             0
# Food Rating        0
# Service Rating     0
# Overall Rating     0
# Often A S          0
# State              0
# City               0
# dtype: int64

# %% [markdown]
# ## What is exploratory data analysis?
# Exploratory data analysis (EDA) is used by data scientists to analyze and investigate data sets and summarize their main characteristics, often employing data visualization methods. It helps determine how best to manipulate data sources to get the answers you need, making it easier for data scientists to discover patterns, spot anomalies, test a hypothesis, or check assumptions.
#
# EDA is primarily used to see what data can reveal beyond the formal modeling or hypothesis testing task and provides a provides a better understanding of data set variables and the relationships between them. It can also help determine if the statistical techniques you are considering for data analysis are appropriate. Originally developed by American mathematician John Tukey in the 1970s, EDA techniques continue to be a widely used method in the data discovery process today.

# %% [markdown]
# ## Overview of dataset  :

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   User ID         200 non-null    int64
#  1   Area code       200 non-null    int64
#  2   Gender          200 non-null    object
#  3   YOB             200 non-null    int64
#  4   Marital Status  186 non-null    object
#  5   Activity        191 non-null    object
#  6   Budget          200 non-null    int64
#  7   Cuisines        192 non-null    object
#  8   Alcohol         200 non-null    object
#  9   Smoker          200 non-null    object
#  10  Food Rating     200 non-null    int64
#  11  Service Rating  200 non-null    int64
#  12  Overall Rating  200 non-null    float64
#  13  Often A S       200 non-null    object
#  14  State           200 non-null    object
#  15  City            200 non-null    object
# dtypes: float64(1), int64(6), object(9)
# memory usage: 25.1+ KB

# %% [markdown]
# ## Number and size of dataset's dimension  :

# %%
df.shape
# Out:
# (200, 16)

# %% [markdown]
# ## Number of all elements in dataset  :

# %%
df.size
# Out:
# 3200

# %% [markdown]
# ## Dimension of dataframe  :

# %%
df.ndim
# Out:
# 2

# %% [markdown]
# ## Statistical measures of dataset  :

# %%
df.describe()
# Out:
#           User ID   Area code          YOB      Budget  Food Rating  \
# count  200.000000  200.000000   200.000000  200.000000   200.000000
# mean   100.500000  141.060000  1984.830000    3.815000     3.220000
# std     57.879185   26.130257    16.809339    1.056578     1.411226
# min      1.000000  101.000000  1955.000000    1.000000     1.000000
# 25%     50.750000  123.000000  1971.000000    3.000000     2.000000
# 50%    100.500000  135.000000  1987.000000    4.000000     3.000000
# 75%    150.250000  158.000000  2000.000000    5.000000     5.000000
# max    200.000000  199.000000  2009.000000    5.000000     5.000000
#
#        Service Rating  Overall Rating
# count      200.000000      200.000000
# mean         3.230000        3.225000
# std          1.526022        1.079445
# min          1.000000        1.000000
# 25%          2.000000        2.500000
# 50%          3.000000        3.000000
# 75%          5.000000        4.000000
# max          5.000000        5.000000

# %% [markdown]
# ## Sample of dataset  :

# %%
df.sample()
# Out:
#     User ID  Area code Gender   YOB Marital Status Activity  Budget Cuisines  \
# 82       83        122   Male  1996        Married  Student       4   French
#
#    Alcohol     Smoker  Food Rating  Service Rating  Overall Rating Often A S  \
# 82    Often  Socially            2               4             3.0        No
#
#    State             City
# 82    NY  Upper West Side

# %% [markdown]
# ## Unique values of all columns  :

# %%
df.nunique()
# Out:
# User ID           200
# Area code          65
# Gender              2
# YOB                46
# Marital Status      2
# Activity            2
# Budget              5
# Cuisines            7
# Alcohol             3
# Smoker              3
# Food Rating         5
# Service Rating      5
# Overall Rating      9
# Often A S           2
# State               4
# City                8
# dtype: int64

# %% [markdown]
# ## Heading of all columns  :

# %%
df.columns
# Out:
# Index(['User ID', 'Area code', 'Gender', 'YOB', 'Marital Status', 'Activity',
#        'Budget', 'Cuisines', 'Alcohol ', 'Smoker', 'Food Rating',
#        'Service Rating', 'Overall Rating', 'Often A S', 'State', 'City'],
#       dtype='object')

# %% [markdown]
# ## Memory each column using in bytes  :

# %%
df.memory_usage()
# Out:
# Index              132
# User ID           1600
# Area code         1600
# Gender            1600
# YOB               1600
# Marital Status    1600
# Activity          1600
# Budget            1600
# Cuisines          1600
# Alcohol           1600
# Smoker            1600
# Food Rating       1600
# Service Rating    1600
# Overall Rating    1600
# Often A S         1600
# State             1600
# City              1600
# dtype: int64

# %% [markdown]
# ## Data type of dataset  :

# %%
df.dtypes
# Out:
# User ID             int64
# Area code           int64
# Gender             object
# YOB                 int64
# Marital Status     object
# Activity           object
# Budget              int64
# Cuisines           object
# Alcohol            object
# Smoker             object
# Food Rating         int64
# Service Rating      int64
# Overall Rating    float64
# Often A S          object
# State              object
# City               object
# dtype: object

# %% [markdown]
# ## Installing Seaborn  :

# %%
pip install seaborn
# Out:
# ...
#    ---------------------------------------- 0.0/294.6 kB ? eta -:--:--
#    - -------------------------------------- 10.2/294.6 kB ? eta -:--:--
#    - -------------------------------------- 10.2/294.6 kB ? eta -:--:--
#    ----- --------------------------------- 41.0/294.6 kB 393.8 kB/s eta 0:00:01
#    -------- ------------------------------ 61.4/294.6 kB 465.5 kB/s eta 0:00:01
#    --------- ----------------------------- 71.7/294.6 kB 435.7 kB/s eta 0:00:01
#    --------- ----------------------------- 71.7/294.6 kB 435.7 kB/s eta 0:00:01
#    --------- ----------------------------- 71.7/294.6 kB 435.7 kB/s eta 0:00:01
#    ------------ -------------------------- 92.2/294.6 kB 327.7 kB/s eta 0:00:01
#    ------------------ ------------------- 143.4/294.6 kB 448.2 kB/s eta 0:00:01
#    ------------------ ------------------- 143.4/294.6 kB 448.2 kB/s eta 0:00:01
#    ------------------ ------------------- 143.4/294.6 kB 448.2 kB/s eta 0:00:01
# ...

# %% [markdown]
# ## Importing  seaborn   :

# %%
import numpy as np

import pandas as pd

import matplotlib as plt

import seaborn as sns

# %% [markdown]
# ## Graph of single and married peoples  :

# %%
sns.displot(df["Marital Status"])

# %% [markdown]
# ## Female and male martial status  :

# %%
sns.jointplot(x="Marital Status" , y="Gender"  , data=df)
